# %% [markdown]
# 2장. VS Code에서 시작하는 데이터 분석 환경
# LLM 기반 데이터 분석 실무 입문 과정의 환경 점검용 실습 노트북입니다.
#
# 학습 목표
# 현재 Notebook이 사용하는 Python 환경과 작업 폴더를 확인합니다.
# 제공된 샘플 데이터를 불러와 기본 구조를 확인합니다.
# 오류 메시지와 실행 환경을 안전하게 정리해 LLM에 질문하는 방법을 익힙니다.
# 1. 실행 환경 확인
# 먼저 현재 Notebook 커널과 작업 폴더를 확인합니다. VS Code에서 프로젝트의 .venv 커널을 선택한 뒤 실행하세요.

# %%
from pathlib import Path
import sys

print('Python 실행 파일:', sys.executable)
print('현재 작업 폴더:', Path.cwd())
# Out:
# Python 실행 파일: c:\dev\llm-data-analysis-course\.venv\Scripts\python.exe
# 현재 작업 폴더: c:\dev\llm-data-analysis-course\notebooks

# %% [markdown]
# 2. 패키지와 데이터 경로 설정
# Notebook의 현재 작업 폴더가 프로젝트 루트인지 notebooks 폴더인지에 따라 상대 경로가 달라질 수 있습니다. 아래 코드는 두 경우를 모두 확인해 데이터 폴더를 선택합니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'data' / 'raw').exists() and (PROJECT_ROOT.parent / 'data' / 'raw').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / 'data' / 'raw'
sns.set_theme(style='whitegrid')

print('프로젝트 루트:', PROJECT_ROOT)
print('데이터 폴더:', DATA_DIR)
print('데이터 폴더 존재 여부:', DATA_DIR.exists())
# Out:
# 프로젝트 루트: c:\dev\llm-data-analysis-course
# 데이터 폴더: c:\dev\llm-data-analysis-course\data\raw
# 데이터 폴더 존재 여부: True

# %% [markdown]
# 3. 샘플 데이터 불러오기
# customers.csv가 없다면 프로젝트 루트의 터미널에서 python scripts/generate_sample_data.py를 먼저 실행하세요.

# %%
customers_path = DATA_DIR / 'customers.csv'

if not customers_path.exists():
    raise FileNotFoundError(
        f'{customers_path} 파일이 없습니다. '
        '프로젝트 루트에서 python scripts/generate_sample_data.py를 실행하세요.'
    )

customers = pd.read_csv(customers_path)
customers.head()
# Out:
#    customer_id name gender  age city signup_date
# 0            1  김수민      F   19   광주  2024-09-02
# 1            2  김정호      F   32   대구  2026-01-16
# 2            3  이경수      F   61   성남  2024-08-26
# 3            4  조영호      F   55   울산  2026-06-27
# 4            5  이예원      F   19   부산  2024-11-27

# %% [markdown]
# 4. 기본 구조 확인
# 행과 열의 개수, 컬럼명, 데이터 타입을 확인합니다.

# %%
print('데이터 크기:', customers.shape)
print('컬럼명:', customers.columns.tolist())
customers.info()
# Out:
# 데이터 크기: (150, 6)
# 컬럼명: ['customer_id', 'name', 'gender', 'age', 'city', 'signup_date']
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  150 non-null    int64
#  1   name         150 non-null    str
#  2   gender       150 non-null    str
#  3   age          150 non-null    int64
#  4   city         150 non-null    str
#  5   signup_date  150 non-null    str
# dtypes: int64(2), str(4)
# memory usage: 11.0 KB

# %% [markdown]
# 12. Notebook에서 실제 실행 환경 검증하기
#
#
#
# 첫 환경 점검 셀은 다음 두 값을 출력합니다.
# [출처] 2장. VS Code에서 시작하는 데이터 분석 환경|작성자 아토믹데브

# %%
from pathlib import Path

import sys

print('Python 실행 파일:', sys.executable)

print('현재 작업 폴더:', Path.cwd())
# Out:
# Python 실행 파일: c:\dev\llm-data-analysis-course\.venv\Scripts\python.exe
# 현재 작업 폴더: c:\dev\llm-data-analysis-course\notebooks

# %% [markdown]
# STEP 14. customers.csv 불러오기
# 14-1. 목적
# Notebook, 커널, 패키지, 데이터 경로가 모두 연결됐는지 최종 확인합니다.
#
# 14-2. 실행
# Notebook의 샘플 데이터 불러오기 셀을 실행합니다.

# %%
customers = pd.read_csv(customers_path)
customers.head()
# Out:
#    customer_id name gender  age city signup_date
# 0            1  김수민      F   19   광주  2024-09-02
# 1            2  김정호      F   32   대구  2026-01-16
# 2            3  이경수      F   61   성남  2024-08-26
# 3            4  조영호      F   55   울산  2026-06-27
# 4            5  이예원      F   19   부산  2024-11-27
